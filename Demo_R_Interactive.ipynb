# %% [markdown]
# <a href="https://colab.research.google.com/github/OlajideFemi/Carbon-Footprint/blob/main/Demo_R_Interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# title: "Demo"
# output: flexdashboard::flex_dashboard
# runtime: shiny
#
# ---
#
# ```{r setup, include=FALSE}
# library(igraph)
# library(visNetwork)
# library(flexdashboard)
# library(shiny)
# ```
#
# Column {.sidebar}
# -----------------------------------------------------------------------
#
#
# ```{r}
# numericInput("n","Number of nodes",value = 10)
# sliderInput("children","Number of children",1,10,2)
# ```
#
# Column
# -----------------------------------------------------------------------
#
# ### Grap viz
# ```{r}
# renderVisNetwork({
#   make_tree(input$n,input$children) %>% visIgraph(layout = "layout_as_tree",circular=T)
# })
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
